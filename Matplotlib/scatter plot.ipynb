# %%
import matplotlib.pyplot as plt

# %%
study_hours = [1, 2, 3, 4, 5, 6, 7, 8, 9]
exam_scores = [40, 45, 50, 55, 60, 65, 75, 85, 90]

# %%
# colors = ['red' if score<60 else "green" for score in exam_scores]
sizes = [score * 2 for score in exam_scores]
plt.scatter(study_hours,exam_scores,c=exam_scores,cmap='viridis',s=sizes)
plt.colorbar(label="score")
plt.grid()
for i in range(len(study_hours)):
    plt.annotate(f's {i+1}',(study_hours[i]+0.2,exam_scores[i]))
plt.xlabel("study hours")
plt.ylabel("exam marks")
plt.title("student analysis")
# Out:
# Text(0.5, 1.0, 'student analysis')
