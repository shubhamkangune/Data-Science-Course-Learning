# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# ...

# %%
df.query("Year > 2019 and IMDb > 5")
# Out:
#              Actor               Film  Year          Genre  \
# 0   Shah Rukh Khan            Pathaan  2023         Action
# 3    Ranbir Kapoor         Brahmastra  2022        Fantasy
# 9    Kartik Aaryan  Bhool Bhulaiyaa 2  2022  Horror Comedy
# 12    bhimashankar             trader  2025         action
#
#     BoxOffice(INR Crore)  IMDb
# 0                 1050.0   7.2
# 3                  431.0   5.6
# 9                  266.0   5.9
# 12                   NaN   9.0

# %%
df.at[12,"Actor"] = "Bhima"

# %%
df.iloc[1,2]
# Out:
# 2017

# %%
df.loc[12]
# Out:
# Actor                    Bhima
# Film                    trader
# Year                      2025
# Genre                   action
# BoxOffice(INR Crore)       NaN
# IMDb                       9.0
# Name: 12, dtype: object

# %%
df.at[0,"Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df[(df['IMDb']>6) | (df["Year"]>2018)]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 12               Bhima                    trader  2025           action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
24+18+8+9

# %%
127-59

# %%
df = df[["Actor","IMDb"]]

# %%
df
# Out:
#                  Actor  IMDb
# 0              shubham   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df.loc[0,"Actor"] = "shubham"
df
# Out:
#                  Actor  IMDb
# 0              shubham   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df
# Out:
#                  Actor  IMDb (0, Actor)
# 0              shubham   7.2    shubham
# 1          Salman Khan   6.0    shubham
# 2           Aamir Khan   8.4    shubham
# 3        Ranbir Kapoor   5.6    shubham
# 4        Ranveer Singh   7.0    shubham
# 5   Ayushmann Khurrana   8.3    shubham
# 6        Rajkummar Rao   7.5    shubham
# 7       Hrithik Roshan   6.5    shubham
# 8         Akshay Kumar   7.0    shubham
# 9        Kartik Aaryan   5.9    shubham
# 10        Varun Dhawan   6.1    shubham
# 11       Vicky Kaushal   8.2    shubham
