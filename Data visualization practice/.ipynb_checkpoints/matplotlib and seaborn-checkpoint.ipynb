# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data
df = pd.read_csv("./datasets/diamonds.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
#                                         Matplotlib practice

# %%
# line plot
plt.plot(df['carat'], df['price'])
plt.title("create vs price line plot")
plt.xlabel("Carat")
plt.ylabel("Price")
plt.savefig('./plots_png/plot1',dpi=300,bbox_inches='tight')
plt.show()

# %%
# scatter plot
plt.scatter(df["carat"], df["price"])
plt.title("create vs price line plot")
plt.xlabel("Carat")
plt.ylabel("Price")
plt.savefig('./plots_png/plot2',dpi=300,bbox_inches='tight')
plt.show()

# %%
# Bar plot
plt.bar(df["cut"].unique(),df.groupby("cut")["price"].mean())
plt.title("Average price by Cut")
plt.xlabel("Cut")
plt.ylabel("Average price")
plt.savefig('./plots_png/plot3',dpi=300,bbox_inches='tight')
plt.show()

# %%
# Histogram
plt.hist(df["price"],bins=20, edgecolor="black")
plt.title("Distribution of price")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.savefig('./plots_png/plot4',dpi=300,bbox_inches='tight')
plt.show()

# %%
# Box plot
plt.boxplot(df["carat"],vert=False)
plt.title("box plot of carat")
plt.xlabel("Carat")
plt.savefig('./plots_png/plot5',dpi=300,bbox_inches='tight')

plt.show()

# %%
# pie chart 
cut_counts = df['cut'].value_counts()
plt.pie(cut_counts,labels=cut_counts.index,autopct='%1.1f%%',startangle=90)
plt.savefig('./plots_png/plot6',dpi=300,bbox_inches='tight')

plt.show()

# %%
# pie chart of color
color_count = df['color'].value_counts()
color = color_count.index
plt.pie(color_count,labels=color,autopct="%1.1f%%",startangle=90)
plt.savefig('./plots_png/plot7',dpi=300,bbox_inches='tight')

plt.show()

# %%
# Heatmap of correlation matrix
correlation = df[['carat','depth','table','price','x','y','z']].corr()
plt.imshow(correlation,cmap="coolwarm",interpolation='none')
plt.colorbar()
plt.xticks(range(len(correlation)),correlation.columns, rotation=90)
plt.yticks(range(len(correlation)),correlation.columns)
plt.title("Heatmap of Correlation Matrix")
plt.savefig('./plots_png/plot8',dpi=300,bbox_inches='tight')
plt.show()

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
# subplots
fig, axes = plt.subplots(2,2,figsize=(12,10))
axes = axes.ravel()

# axes[0].hist(df['carat'],bins=10,edgecolor='black')
# axes[0].set_title("Histrogram of carat")
# axes[0].set_xlabel("Carat")
# axes[0].set_ylabel("Frequency")

axes[0].hist(df['price'],bins=12,edgecolor="black")
axes[0].set_title("Histrogram of price")
axes[0].set_xlabel("Price")
axes[0].set_ylabel("Frequency")

cut_counts = df['cut'].value_counts()
axes[1].pie(cut_counts,labels=cut_counts.index,autopct='%1.1f%%',startangle=90)
axes[1].set_title("Pie Chart of Cuts")

axes[2].scatter(df['carat'],df['price'])
axes[2].set_title("Histrogram X dimentions")
axes[2].set_xlabel("Carat")
axes[2].set_ylabel("Price")

axes[3].bar(df['cut'].unique(),df.groupby("cut")['price'].mean())
axes[3].set_title("Histrogram Y dimention")
axes[3].set_xlabel("Cut")
axes[3].set_ylabel("Average Price")

plt.tight_layout()
plt.savefig('./plots_png/plot9',dpi=300,bbox_inches='tight')

plt.show()

# %%
df['cut'].unique(),df.groupby("cut")["price"].mean()
# Out:
# (array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object),
#  cut
#  Fair         4358.757764
#  Good         3928.864452
#  Ideal        3457.541970
#  Premium      4584.257704
#  Very Good    3981.759891
#  Name: price, dtype: float64)

# %%
df.groupby("cut")["price"].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
#                                         Seaborn Practice

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# seaborn scatter plot
sns.scatterplot(x="carat",y="price",data=df)
plt.savefig('./plots_png/plot10',dpi=300,bbox_inches='tight')

plt.show()

# %%
# add hue
sns.scatterplot(x="carat",y="price",data=df,hue="cut")
plt.savefig('./plots_png/plot11',dpi=300,bbox_inches='tight')
plt.show()

# %%
# line plot
sns.lineplot(x="carat",y="price",data=df)
plt.title("Seaborn line plot vs carat ")
plt.savefig('./plots_png/plot12',dpi=300,bbox_inches='tight')

plt.show()

# %%
# seaborn line plot
sns.lineplot(x="carat",y="price",data=df,hue="cut")
plt.title("Seaborn line plot vs carat with hue='cut'")
plt.savefig('./plots_png/plot13',dpi=300,bbox_inches='tight')

plt.show()

# %%
g = sns.FacetGrid(df,col='cut',col_wrap=3,height=4)
g.map(sns.lineplot,"carat","price")
g.add_legend()
plt.savefig('./plots_png/plot14',dpi=300,bbox_inches='tight')

plt.show()

# %%
import time
start = time.time()
figure = plt.figure(figsize=(12,3))
sns.lineplot(x='carat',y='price',hue='cut',data=df)
plt.title("Seaborn line plot carat vs price")
end = time.time()
print(end-start)
plt.savefig('./plots_png/plot15',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# 16.658324241638184

# %%
# box plot by using sns
sns.boxplot(x= 'cut',y='price',data=df)
plt.title("Box plot of Price by Cut")
plt.savefig('./plots_png/plot16',dpi=300,bbox_inches='tight')

plt.show()

# %%
fugure = plt.figure(figsize=(12,3))
sns.boxplot(x='cut',y="price",data=df,hue='color')
plt.title("Box plot of Price by Cut")
plt.savefig('./plots_png/plot17',dpi=300,bbox_inches='tight')

plt.show()

# %%
# violin plot
sns.violinplot(x="cut",y='price',data=df)
plt.title("Violin plot of Price by Cut")
plt.savefig('./plots_png/plot18',dpi=300,bbox_inches='tight')

plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
sns.countplot(x='cut',data=df)
plt.yscale('log')
plt.title("Count plot of Cut")
plt.savefig('./plots_png/plot19',dpi=300,bbox_inches='tight')

plt.show()

# %%
figure = plt.figure(figsize=(12,3))
sns.countplot(x='cut',data=df,hue="color")
plt.title("Count plot of Cut")
plt.savefig('./plots_png/plot20',dpi=300,bbox_inches='tight')

plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# Pair plot
import time
start = time.time()
sns.pairplot(df,hue="cut")
plt.title("Pair Plot of Diamond Attribute")
end = time.time()
plt.savefig('./plots_png/plot21',dpi=300,bbox_inches='tight')
print(end-start)

plt.show()
# Out:
# 67.50216722488403

# %%
g = sns.FacetGrid(df,col="color",col_wrap=3)
g.map(plt.hist,'price',bins=10,edgecolor='black')
plt.savefig('./plots_png/plot22',dpi=300,bbox_inches='tight')

plt.show()

# %%
# Setting seaborn style
sns.set_style('whitegrid')
sns.set_context('paper')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
sns.scatterplot(x='carat',y='price',data=df)
plt.title("Carat plot with whitegrid style and notebook context")
plt.savefig('./plots_png/plot23',dpi=300,bbox_inches='tight')

plt.show()
